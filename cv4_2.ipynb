# %% [markdown]
# ## 04. Generalizace polynomického modelu

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
np.random.seed(0)

# %%
# Data 
# Generování dat 
def fun(x, noise):
    """Základní funkce"""
    return .6 * np.sin(x*6) + x + (x ** .8) * noise

def train_test_data(n_samples, noise_factor): 
    """Generování"""
    
    # train 
    np.random.seed(0)
    X_train = np.sort(np.random.rand(n_samples))
    noise_train = np.random.rand(n_samples) * noise_factor
    y_train = fun(X_train, noise_train) 
    X_train = X_train.reshape(-1, 1)
    
    # test 
    X_test = np.sort(np.random.rand(n_samples))
    noise_test = np.random.rand(n_samples) * noise_factor
    y_test = fun(X_test, noise_test)
    X_test = X_test.reshape(-1, 1)
    
    return X_train, y_train, X_test, y_test

# %%
X_train.shape
# Out:
# (10, 1)

# %%
X_test.shape
# Out:
# (10, 1)

# %%
# Příprava dat
noise_factor = 0.5
n_samples = 30 

X_train, y_train, X_test, y_test = train_test_data(n_samples, noise_factor)

# %%
# Základní funkce
X_fun = np.linspace(0, 1, 100)
noise_fun = np.ones(100) / 2. * noise_factor
y_fun = fun(X_fun, noise_fun)

# %%
# Vykreslete základní funkci   
plt.scatter(X_train, y_train)
plt.plot(X_fun, y_fun, label='Funkce')

# %%
# Parametrizujte polynomický model (stupeň = 10)
# Transformujme vstupni data na polynomialni
stupne = 4
# definujme prvky
poly = PolynomialFeatures(degree=stupne, include_bias=False)
# transformujme trenovaci data
polynomial_features = poly.fit_transform(X_train.reshape(-1, 1))

# %%
polynomial_features.shape
# Out:
# (30, 4)

# %%
y_train.shape
# Out:
# (30,)

# %%
model = LinearRegression()
model.fit(polynomial_features, y_train.reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_train_pred.shape
# Out:
# (30, 1)

# %%
y_train_pred.shape
# Out:
# (30, 1)

# %%
# Vyhodnoťte přesnost trénování modelu 
y_train_pred = model.predict(polynomial_features)
MSE_train = mean_squared_error(y_train, y_train_pred)
print(round(MSE_train, 20))
# Out:
# 0.008209055674040656

# %%
# Generalizační chyba  
y_test_pred = model.predict(poly.fit_transform(X_test.reshape(-1, 1)))
MSE_test = mean_squared_error(y_test, y_test_pred)
print(MSE_test)
# Out:
# 0.008413698707618157

# %%
MSE_test - MSE_train
# Out:
# 0.00020464303357750104

# %%
# Vykreslete model 
X_model = np.linspace(0.1, 1.0, 100)
y_model = model.predict(poly.fit_transform(X_model.reshape(-1, 1)))

plt.scatter(X_train, y_train, label='trenovani', color='blue')
plt.scatter(X_test, y_test, label='testovani', color='green')
plt.plot(X_model, y_model)
plt.ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
# Vykreslete model 
X_model = np.linspace(0.1, 1.0, 100)
y_model = model.predict(poly.fit_transform(X_model.reshape(-1, 1)))

plt.scatter(X_train, y_train, label='trenovani', color='blue')
plt.scatter(X_test, y_test, label='testovani', color='green')
plt.plot(X_model, y_model)
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
# Vykreslete model 
X_model = np.linspace(0.1, 1.0, 100)
y_model = model.predict(poly.fit_transform(X_model.reshape(-1, 1)))

plt.scatter(X_train, y_train, label='trenovani', color='blue')
plt.scatter(X_test, y_test, label='testovani', color='green')
plt.plot(X_model, y_model)
plt.ylim(0, 2)
# Out:
# (0.0, 2.0)

# %%
# Vykreslete model 
X_model = np.linspace(0.1, 1.0, 100)
y_model = model.predict(poly.fit_transform(X_model.reshape(-1, 1)))

plt.scatter(X_train, y_train, label='trenovani', color='blue', alpha=0.1)
plt.scatter(X_test, y_test, label='testovani', color='green', alpha=0.1)
plt.plot(X_model, y_model)
plt.ylim(0, 2)
# Out:
# (0.0, 2.0)

# %%
# Vykreslete model 
X_model = np.linspace(0.0, 1.0, 100)
y_model = model.predict(poly.fit_transform(X_model.reshape(-1, 1)))

plt.scatter(X_train, y_train, label='trenovani', color='blue', alpha=0.1)
plt.scatter(X_test, y_test, label='testovani', color='green', alpha=0.1)
plt.plot(X_model, y_model, color='red')
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
# Vykreslete model 
X_model = np.linspace(0.0, 1.0, 100)
y_model = model.predict(poly.fit_transform(X_model.reshape(-1, 1)))

plt.scatter(X_train, y_train, label='trenovani', color='blue', alpha=0.1)
plt.scatter(X_test, y_test, label='testovani', color='green', alpha=0.1)
plt.plot(X_model, y_model, color='red')
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
# Vykreslete model 
X_model = np.linspace(0.0, 1.0, 100)
y_model = model.predict(poly.fit_transform(X_model.reshape(-1, 1)))

plt.scatter(X_train, y_train, label='trenovani', color='blue', alpha=0.1)
plt.scatter(X_test, y_test, label='testovani', color='green', alpha=0.1)
plt.plot(X_model, y_model, color='red')
plt.ylim(0, 2)
# Out:
# (0.0, 2.0)

# %%
# Vykreslete model 
X_model = np.linspace(0.0, 1.0, 100)
y_model = model.predict(poly.fit_transform(X_model.reshape(-1, 1)))

plt.scatter(X_train, y_train, label='trenovani', color='blue', alpha=0.3)
plt.scatter(X_test, y_test, label='testovani', color='green', alpha=0.3)
plt.plot(X_model, y_model, color='red')
plt.ylim(0, 2)
# Out:
# (0.0, 2.0)
